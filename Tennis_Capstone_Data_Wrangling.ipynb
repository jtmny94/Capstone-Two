# %%
# import libraries and modules
import kagglehub
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime, timedelta
from kagglehub.datasets import KaggleDatasetAdapter
from fuzzywuzzy import process

# %%
# importing Sackmann tennis match data - excluding 2025 as season has not finished yet

years = range(2000, 2024)  # 2000-2024
base_url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/"

dfs = []
for year in years:
    url = f"{base_url}atp_matches_{year}.csv"
    try:
        df = pd.read_csv(url)
        df['year'] = year 
        dfs.append(df)
    except Exception as e:
        print(f"Could not load {url}: {e}")

# Combine into one DataFrame
all_matches_df = pd.concat(dfs, ignore_index=True)

# %%
all_matches_df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-301     Auckland    Hard         32             A      20000110
# 1   2000-301     Auckland    Hard         32             A      20000110
# 2   2000-301     Auckland    Hard         32             A      20000110
# 3   2000-301     Auckland    Hard         32             A      20000110
# 4   2000-301     Auckland    Hard         32             A      20000110
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0          1     103163          1.0          NaN  ...     39.0     29.0
# 1          2     102607          NaN            Q  ...     25.0     18.0
# 2          3     103252          NaN          NaN  ...     20.0      7.0
# 3          4     103507          7.0          NaN  ...     29.0     14.0
# 4          5     102103          NaN            Q  ...     34.0     18.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points loser_rank  \
# 0     17.0       4.0        7.0         11.0              1612.0       63.0
# 1     12.0       3.0        6.0        211.0               157.0       49.0
# 2      8.0       7.0       11.0         48.0               726.0       59.0
# 3     10.0       6.0        8.0         45.0               768.0       61.0
# 4     12.0       5.0        9.0        167.0               219.0       34.0
#
#   loser_rank_points  year
# 0             595.0  2000
# 1             723.0  2000
# 2             649.0  2000
# 3             616.0  2000
# 4             873.0  2000
#
# [5 rows x 50 columns]

# %%
all_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71830 entries, 0 to 71829
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          71830 non-null  object
#  1   tourney_name        71830 non-null  object
#  2   surface             71777 non-null  object
#  3   draw_size           71830 non-null  int64
#  4   tourney_level       71830 non-null  object
#  5   tourney_date        71830 non-null  int64
#  6   match_num           71830 non-null  int64
#  7   winner_id           71830 non-null  int64
#  8   winner_seed         29826 non-null  float64
#  9   winner_entry        9029 non-null   object
#  10  winner_name         71830 non-null  object
#  11  winner_hand         71830 non-null  object
#  12  winner_ht           70424 non-null  float64
#  13  winner_ioc          71830 non-null  object
#  14  winner_age          71826 non-null  float64
#  15  loser_id            71830 non-null  int64
#  16  loser_seed          16481 non-null  float64
#  17  loser_entry         14704 non-null  object
#  18  loser_name          71830 non-null  object
#  19  loser_hand          71826 non-null  object
#  20  loser_ht            68971 non-null  float64
#  21  loser_ioc           71830 non-null  object
#  22  loser_age           71828 non-null  float64
#  23  score               71830 non-null  object
#  24  best_of             71830 non-null  int64
#  25  round               71830 non-null  object
#  26  minutes             63894 non-null  float64
#  27  w_ace               65370 non-null  float64
#  28  w_df                65370 non-null  float64
#  29  w_svpt              65370 non-null  float64
#  30  w_1stIn             65370 non-null  float64
#  31  w_1stWon            65370 non-null  float64
#  32  w_2ndWon            65370 non-null  float64
#  33  w_SvGms             65371 non-null  float64
#  34  w_bpSaved           65370 non-null  float64
#  35  w_bpFaced           65370 non-null  float64
#  36  l_ace               65370 non-null  float64
#  37  l_df                65370 non-null  float64
#  38  l_svpt              65370 non-null  float64
#  39  l_1stIn             65370 non-null  float64
#  40  l_1stWon            65370 non-null  float64
#  41  l_2ndWon            65370 non-null  float64
#  42  l_SvGms             65371 non-null  float64
#  43  l_bpSaved           65370 non-null  float64
#  44  l_bpFaced           65370 non-null  float64
#  45  winner_rank         71274 non-null  float64
#  46  winner_rank_points  71274 non-null  float64
#  47  loser_rank          70402 non-null  float64
#  48  loser_rank_points   70402 non-null  float64
#  49  year                71830 non-null  int64
# dtypes: float64(29), int64(7), object(14)
# memory usage: 27.4+ MB

# %%
# Converting tourney_date to datetime
all_matches_df['tourney_date'] = pd.to_datetime(all_matches_df['tourney_date'].astype(str), format='%Y%m%d')

# %%
all_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71830 entries, 0 to 71829
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          71830 non-null  object
#  1   tourney_name        71830 non-null  object
#  2   surface             71777 non-null  object
#  3   draw_size           71830 non-null  int64
#  4   tourney_level       71830 non-null  object
#  5   tourney_date        71830 non-null  datetime64[ns]
#  6   match_num           71830 non-null  int64
#  7   winner_id           71830 non-null  int64
#  8   winner_seed         29826 non-null  float64
#  9   winner_entry        9029 non-null   object
#  10  winner_name         71830 non-null  object
#  11  winner_hand         71830 non-null  object
#  12  winner_ht           70424 non-null  float64
#  13  winner_ioc          71830 non-null  object
#  14  winner_age          71826 non-null  float64
#  15  loser_id            71830 non-null  int64
#  16  loser_seed          16481 non-null  float64
#  17  loser_entry         14704 non-null  object
#  18  loser_name          71830 non-null  object
#  19  loser_hand          71826 non-null  object
#  20  loser_ht            68971 non-null  float64
#  21  loser_ioc           71830 non-null  object
#  22  loser_age           71828 non-null  float64
#  23  score               71830 non-null  object
#  24  best_of             71830 non-null  int64
#  25  round               71830 non-null  object
#  26  minutes             63894 non-null  float64
#  27  w_ace               65370 non-null  float64
#  28  w_df                65370 non-null  float64
#  29  w_svpt              65370 non-null  float64
#  30  w_1stIn             65370 non-null  float64
#  31  w_1stWon            65370 non-null  float64
#  32  w_2ndWon            65370 non-null  float64
#  33  w_SvGms             65371 non-null  float64
#  34  w_bpSaved           65370 non-null  float64
#  35  w_bpFaced           65370 non-null  float64
#  36  l_ace               65370 non-null  float64
#  37  l_df                65370 non-null  float64
#  38  l_svpt              65370 non-null  float64
#  39  l_1stIn             65370 non-null  float64
#  40  l_1stWon            65370 non-null  float64
#  41  l_2ndWon            65370 non-null  float64
#  42  l_SvGms             65371 non-null  float64
#  43  l_bpSaved           65370 non-null  float64
#  44  l_bpFaced           65370 non-null  float64
#  45  winner_rank         71274 non-null  float64
#  46  winner_rank_points  71274 non-null  float64
#  47  loser_rank          70402 non-null  float64
#  48  loser_rank_points   70402 non-null  float64
#  49  year                71830 non-null  int64
# dtypes: datetime64[ns](1), float64(29), int64(6), object(14)
# memory usage: 27.4+ MB

# %%
# Count NaN
all_matches_df.isna().sum()
# Out:
# tourney_id                0
# tourney_name              0
# surface                  53
# draw_size                 0
# tourney_level             0
# tourney_date              0
# match_num                 0
# winner_id                 0
# winner_seed           42004
# winner_entry          62801
# winner_name               0
# winner_hand               0
# winner_ht              1406
# winner_ioc                0
# winner_age                4
# loser_id                  0
# loser_seed            55349
# loser_entry           57126
# loser_name                0
# loser_hand                4
# loser_ht               2859
# loser_ioc                 0
# loser_age                 2
# score                     0
# best_of                   0
# round                     0
# minutes                7936
# w_ace                  6460
# w_df                   6460
# w_svpt                 6460
# w_1stIn                6460
# w_1stWon               6460
# w_2ndWon               6460
# w_SvGms                6459
# w_bpSaved              6460
# w_bpFaced              6460
# l_ace                  6460
# l_df                   6460
# l_svpt                 6460
# l_1stIn                6460
# l_1stWon               6460
# l_2ndWon               6460
# l_SvGms                6459
# l_bpSaved              6460
# l_bpFaced              6460
# winner_rank             556
# winner_rank_points      556
# loser_rank             1428
# loser_rank_points      1428
# year                      0
# dtype: int64

# %%
for col in all_matches_df.columns: 
    null_pct = all_matches_df[col].isnull().mean() * 100
    print(f"{col}: {null_pct:.2f}%")
# Out:
# tourney_id: 0.00%
# tourney_name: 0.00%
# surface: 0.07%
# draw_size: 0.00%
# tourney_level: 0.00%
# tourney_date: 0.00%
# match_num: 0.00%
# winner_id: 0.00%
# winner_seed: 58.48%
# winner_entry: 87.43%
# winner_name: 0.00%
# winner_hand: 0.00%
# winner_ht: 1.96%
# winner_ioc: 0.00%
# winner_age: 0.01%
# loser_id: 0.00%
# loser_seed: 77.06%
# loser_entry: 79.53%
# loser_name: 0.00%
# loser_hand: 0.01%
# loser_ht: 3.98%
# loser_ioc: 0.00%
# loser_age: 0.00%
# score: 0.00%
# best_of: 0.00%
# round: 0.00%
# minutes: 11.05%
# w_ace: 8.99%
# w_df: 8.99%
# w_svpt: 8.99%
# w_1stIn: 8.99%
# w_1stWon: 8.99%
# w_2ndWon: 8.99%
# w_SvGms: 8.99%
# w_bpSaved: 8.99%
# w_bpFaced: 8.99%
# l_ace: 8.99%
# l_df: 8.99%
# l_svpt: 8.99%
# l_1stIn: 8.99%
# l_1stWon: 8.99%
# l_2ndWon: 8.99%
# l_SvGms: 8.99%
# l_bpSaved: 8.99%
# l_bpFaced: 8.99%
# winner_rank: 0.77%
# winner_rank_points: 0.77%
# loser_rank: 1.99%
# loser_rank_points: 1.99%
# year: 0.00%

# %%
# Import of data with betting odds from 2001 through 2025, odds data unavailable until 2001

all_years_df = pd.DataFrame()

for year in range(2001, 2025):
    try:
        df = pd.read_excel(f'tennis_data_co_uk_alldata/{year}.xls')
        print(f'Loaded {year}.xls')
    except FileNotFoundError:
        try:
            df = pd.read_excel(f'tennis_data_co_uk_alldata/{year}.xlsx')
            print(f'Loaded {year}.xlsx')
        except FileNotFoundError:
            print(f'No file found for year {year}')
            continue
    all_years_df = pd.concat([all_years_df, df], ignore_index=True)
# Out:
# Loaded 2001.xls
# Loaded 2002.xls
# Loaded 2003.xls
# Loaded 2004.xls
# Loaded 2005.xls
# Loaded 2006.xls
# Loaded 2007.xls
# Loaded 2008.xls
# Loaded 2009.xls
# Loaded 2010.xls
# Loaded 2011.xls
# Loaded 2012.xls
# /Users/jordanwork/Desktop/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2013.xlsx
# /Users/jordanwork/Desktop/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2014.xlsx
# /Users/jordanwork/Desktop/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2015.xlsx
# /Users/jordanwork/Desktop/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# Loaded 2016.xlsx
# Loaded 2017.xlsx
# Loaded 2018.xlsx
# Loaded 2019.xlsx
# Loaded 2020.xlsx
# Loaded 2021.xlsx
# Loaded 2022.xlsx
# Loaded 2023.xlsx
# Loaded 2024.xlsx

# %%
all_years_df.head()
# Out:
#    ATP  Location          Tournament       Date         Series    Court  \
# 0    1  Adelaide  AAPT Championships 2001-01-01  International  Outdoor
# 1    1  Adelaide  AAPT Championships 2001-01-01  International  Outdoor
# 2    1  Adelaide  AAPT Championships 2001-01-01  International  Outdoor
# 3    1  Adelaide  AAPT Championships 2001-01-01  International  Outdoor
# 4    1  Adelaide  AAPT Championships 2001-01-01  International  Outdoor
#
#   Surface      Round  Best of        Winner  ... UBW  UBL LBW  LBL  SJW SJL  \
# 0    Hard  1st Round      3.0    Clement A.  ... NaN  NaN NaN  NaN  NaN NaN
# 1    Hard  1st Round      3.0  Goldstein P.  ... NaN  NaN NaN  NaN  NaN NaN
# 2    Hard  1st Round      3.0       Haas T.  ... NaN  NaN NaN  NaN  NaN NaN
# 3    Hard  1st Round      3.0     Henman T.  ... NaN  NaN NaN  NaN  NaN NaN
# 4    Hard  1st Round      3.0     Hewitt L.  ... NaN  NaN NaN  NaN  NaN NaN
#
#   MaxW MaxL AvgW  AvgL
# 0  NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN   NaN
#
# [5 rows x 54 columns]

# %%
all_years_df['Date'] = pd.to_datetime(all_years_df['Date'].astype(str), format='%Y-%m-%d')

# %%
all_years_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63739 entries, 0 to 63738
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         63739 non-null  int64
#  1   Location    63739 non-null  object
#  2   Tournament  63739 non-null  object
#  3   Date        63739 non-null  datetime64[ns]
#  4   Series      63739 non-null  object
#  5   Court       63739 non-null  object
#  6   Surface     63739 non-null  object
#  7   Round       63739 non-null  object
#  8   Best of     63724 non-null  float64
#  9   Winner      63739 non-null  object
#  10  Loser       63739 non-null  object
#  11  WRank       63717 non-null  float64
#  12  LRank       63625 non-null  object
#  13  W1          63387 non-null  float64
#  14  L1          63390 non-null  float64
#  15  W2          62805 non-null  object
#  16  L2          62806 non-null  object
#  17  W3          29765 non-null  object
#  18  L3          29764 non-null  object
#  19  W4          6013 non-null   float64
#  20  L4          6013 non-null   float64
#  21  W5          2288 non-null   float64
#  22  L5          2288 non-null   float64
#  23  Wsets       63414 non-null  float64
#  24  Lsets       63412 non-null  float64
#  25  Comment     63739 non-null  object
#  26  CBW         17506 non-null  float64
#  27  CBL         17506 non-null  float64
#  28  GBW         5055 non-null   float64
#  29  GBL         5055 non-null   float64
#  30  IWW         13358 non-null  float64
#  31  IWL         13358 non-null  float64
#  32  SBW         5424 non-null   float64
#  33  SBL         5424 non-null   float64
#  34  B365W       57986 non-null  float64
#  35  B365L       58009 non-null  float64
#  36  B&WW        1097 non-null   float64
#  37  B&WL        1097 non-null   float64
#  38  EXW         39411 non-null  object
#  39  EXL         39416 non-null  float64
#  40  PSW         51678 non-null  float64
#  41  PSL         51678 non-null  float64
#  42  WPts        50492 non-null  float64
#  43  LPts        50403 non-null  float64
#  44  UBW         10671 non-null  float64
#  45  UBL         10671 non-null  float64
#  46  LBW         28131 non-null  float64
#  47  LBL         28142 non-null  float64
#  48  SJW         15572 non-null  float64
#  49  SJL         15579 non-null  float64
#  50  MaxW        37133 non-null  float64
#  51  MaxL        37133 non-null  float64
#  52  AvgW        37133 non-null  float64
#  53  AvgL        37133 non-null  float64
# dtypes: datetime64[ns](1), float64(37), int64(1), object(15)
# memory usage: 26.3+ MB

# %%
# Creating sets to find overlap in the two 
set_tournament = set(all_years_df['Tournament'].dropna().unique())
set_tourney_name = set(all_matches_df['tourney_name'].dropna().unique())

# Find the intersection
overlap = set_tournament.intersection(set_tourney_name)

print(f"Number of overlapping tournaments: {len(overlap)}")
print("Some overlapping values:", list(overlap)[:10])
# Out:
# Number of overlapping tournaments: 9
# Some overlapping values: ['Great Ocean Road Open', 'Australian Open', 'Masters Cup', 'Monte Carlo Masters', 'Murray River Open', 'Shanghai Masters', 'US Open', 'Madrid Masters', 'Wimbledon']

# %%
# Clean column names

def clean_names(series):
    return (series.str.lower()                    # lowercase
                  .str.strip()                    # remove leading/trailing spaces
                  .str.replace(r'[^a-z0-9 ]', '', regex=True)  # remove punctuation/special chars
                  .str.replace(r'\s+', ' ', regex=True)       # collapse multiple spaces
           )

all_years_df['Tournament_clean'] = clean_names(all_years_df['Tournament'].astype(str))
all_matches_df['tourney_name_clean'] = clean_names(all_matches_df['tourney_name'].astype(str))

# %%
# Get unique cleaned tournament names from all_matches_df
tourneys = all_matches_df['tourney_name_clean'].dropna().unique()

def find_best_match(name, choices, threshold=90):
    match, score = process.extractOne(name, choices)
    if score >= threshold:
        return match
    else:
        return None

# mapping from all_years_df cleaned names to best matches in all_matches_df
mapping = {}
for name in all_years_df['Tournament_clean'].dropna().unique():
    best_match = find_best_match(name, tourneys)
    if best_match:
        mapping[name] = best_match

print(mapping)
# Out:
# {'australian open': 'australian open', 'milan indoors': 'milan', 'copenhagen open': 'copenhagen', 'marseille open': 'marseille', 'dubai championships': 'dubai', 'estoril open': 'estoril', 'monte carlo masters': 'monte carlo masters', 'verizon tennis challenge': 'halle', 'mallorca open': 'mallorca', 'hamburg tms': 'hamburg', 'nottingham open': 'nottingham', 'wimbledon': 'wimbledon', 'gstaad open': 'gstaad', 'us open': 'us open', 'grand prix de lyon': 'lyon', 'stuttgart tms': 'stuttgart', 'st petersburg open': 'st petersburg', 'stockholm open': 'stockholm', 'masters cup': 'masters cup', 'queens club': 'queens club', 'madrid masters': 'madrid masters', 'cam open comunidad valenciana': 'valencia', 'indesit atp milano indoor': 'milan', 'atp buenos aires 2004': 'buenos aires', 'atp buenos aires 2005': 'buenos aires', 'dubai duty free mens open': 'dubai', 'open de tenis comunidad valenciana': 'valencia', 'next generation adelaide international': 'adelaide', 'chennai open': 'chennai', 'sydney international': 'sydney', 'pbz zagreb indoors': 'zagreb', 'dubai tennis championships': 'dubai', 'the nottingham open': 'nottingham', 'indianapolis tennis championships': 'indianapolis', 'austrian open': 'australian open', 'brisbane international': 'brisbane', 'shanghai masters': 'shanghai masters', 'valencia open 500': 'valencia', 'open de nice cte dazur': 'nice', 'unicef open': 'nice', 'atlanta tennis championships': 'atlanta', 'winstonsalem open at wake forest university': 'winstonsalem', 'bbt atlanta open': 'atlanta', 'crdit agricole suisse open gstaad': 'gstaad', 'delray beach open': 'delray beach', 'dusseldorf open': 'dusseldorf', 'shenzhen open': 'shenzhen', 'memphis open': 'memphis', 'millenium estoril open': 'estoril', 'istanbul open': 'istanbul', 'geneva open': 'geneva', 'suisse open gstaad': 'gstaad', 'garanti koza sofia open': 'sofia', 'chengdu open': 'chengdu', 'lyon open': 'lyon', 'antalya open': 'antalya', 'new york open': 'new york', 'millennium estoril open': 'estoril', 'eastbourne international': 'eastbourne', 'cordoba open': 'cordoba', 'sofia open': 'sofia', 'halle open': 'halle', 'queens club championships': 'queens club', 'zhuhai open': 'zhuhai', 'adelaide international': 'adelaide', 'astana open': 'astana', 'great ocean road open': 'great ocean road open', 'murray river open': 'murray river open', 'singapore open': 'singapore', 'barcelona open': 'barcelona', 'belgrade open': 'belgrade', 'mallorca championships': 'mallorca', 'san diego open': 'san diego', 'vienna open': 'vienna', 'adelaide international 1': 'adelaide', 'melbourne summer set': 'melbourne', 'adelaide international 2': 'adelaide', 'sydney tennis classic': 'sydney', 'dallas open': 'dallas', 'atlanta open': 'atlanta', 'los cabos open': 'los cabos', 'tel aviv open': 'tel aviv', 'gijon open': 'gijon', 'stuttgart open': 'stuttgart', 'zhuhai championships': 'zhuhai', 'hong kong tennis open': 'hong kong'}

# %%
# Reverse the mapping so we can join on the official tournament name

reverse_mapping = {v: k for k, v in mapping.items()}
all_matches_df['mapped_tourney_name'] = all_matches_df['tourney_name_clean'].map(reverse_mapping)

# %%
all_years_df['year'] = all_years_df['Date'].dt.year

# %%
# Standardizing player names for matching: 

def clean_player_names(series):
    return (series.str.lower()
                  .str.strip()
                  .str.replace(r'[^a-z ]', '', regex=True)
                  .str.replace(r'\s+', ' ', regex=True)
           )

all_years_df['Winner_clean'] = clean_player_names(all_years_df['Winner'].astype(str))
all_years_df['Loser_clean'] = clean_player_names(all_years_df['Loser'].astype(str))

all_matches_df['winner_name_clean'] = clean_player_names(all_matches_df['winner_name'].astype(str))
all_matches_df['loser_name_clean'] = clean_player_names(all_matches_df['loser_name'].astype(str))

# %%
years_sub = all_years_df[['Tournament_clean', 'year', 'Winner_clean', 'Loser_clean', 'B365W', 'B365L']]

# %%
merged_df = all_matches_df.merge(years_sub,left_on=['mapped_tourney_name', 'year', 'winner_name_clean', 'loser_name_clean'],
                                 right_on=['Tournament_clean', 'year', 'Winner_clean', 'Loser_clean'], how='left')

# %%
merged_df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2000-301     Auckland    Hard         32             A   2000-01-10
# 1   2000-301     Auckland    Hard         32             A   2000-01-10
# 2   2000-301     Auckland    Hard         32             A   2000-01-10
# 3   2000-301     Auckland    Hard         32             A   2000-01-10
# 4   2000-301     Auckland    Hard         32             A   2000-01-10
#
#    match_num  winner_id  winner_seed winner_entry  ...  year  \
# 0          1     103163          1.0          NaN  ...  2000
# 1          2     102607          NaN            Q  ...  2000
# 2          3     103252          NaN          NaN  ...  2000
# 3          4     103507          7.0          NaN  ...  2000
# 4          5     102103          NaN            Q  ...  2000
#
#   tourney_name_clean  mapped_tourney_name    winner_name_clean  \
# 0           auckland                  NaN           tommy haas
# 1           auckland                  NaN        juan balcells
# 2           auckland                  NaN       alberto martin
# 3           auckland                  NaN  juan carlos ferrero
# 4           auckland                  NaN         michael sell
#
#       loser_name_clean  Tournament_clean  Winner_clean Loser_clean B365W B365L
# 0         jeff tarango               NaN           NaN         NaN   NaN   NaN
# 1     franco squillari               NaN           NaN         NaN   NaN   NaN
# 2  alberto berasategui               NaN           NaN         NaN   NaN   NaN
# 3        roger federer               NaN           NaN         NaN   NaN   NaN
# 4       nicolas escude               NaN           NaN         NaN   NaN   NaN
#
# [5 rows x 59 columns]

# %%
merged_df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'year', 'tourney_name_clean', 'mapped_tourney_name',
#        'winner_name_clean', 'loser_name_clean', 'Tournament_clean',
#        'Winner_clean', 'Loser_clean', 'B365W', 'B365L'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71830 entries, 0 to 71829
# Data columns (total 59 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tourney_id           71830 non-null  object
#  1   tourney_name         71830 non-null  object
#  2   surface              71777 non-null  object
#  3   draw_size            71830 non-null  int64
#  4   tourney_level        71830 non-null  object
#  5   tourney_date         71830 non-null  datetime64[ns]
#  6   match_num            71830 non-null  int64
#  7   winner_id            71830 non-null  int64
#  8   winner_seed          29826 non-null  float64
#  9   winner_entry         9029 non-null   object
#  10  winner_name          71830 non-null  object
#  11  winner_hand          71830 non-null  object
#  12  winner_ht            70424 non-null  float64
#  13  winner_ioc           71830 non-null  object
#  14  winner_age           71826 non-null  float64
#  15  loser_id             71830 non-null  int64
#  16  loser_seed           16481 non-null  float64
#  17  loser_entry          14704 non-null  object
#  18  loser_name           71830 non-null  object
#  19  loser_hand           71826 non-null  object
#  20  loser_ht             68971 non-null  float64
#  21  loser_ioc            71830 non-null  object
#  22  loser_age            71828 non-null  float64
#  23  score                71830 non-null  object
#  24  best_of              71830 non-null  int64
#  25  round                71830 non-null  object
#  26  minutes              63894 non-null  float64
#  27  w_ace                65370 non-null  float64
#  28  w_df                 65370 non-null  float64
#  29  w_svpt               65370 non-null  float64
#  30  w_1stIn              65370 non-null  float64
#  31  w_1stWon             65370 non-null  float64
#  32  w_2ndWon             65370 non-null  float64
#  33  w_SvGms              65371 non-null  float64
#  34  w_bpSaved            65370 non-null  float64
#  35  w_bpFaced            65370 non-null  float64
#  36  l_ace                65370 non-null  float64
#  37  l_df                 65370 non-null  float64
#  38  l_svpt               65370 non-null  float64
#  39  l_1stIn              65370 non-null  float64
#  40  l_1stWon             65370 non-null  float64
#  41  l_2ndWon             65370 non-null  float64
#  42  l_SvGms              65371 non-null  float64
#  43  l_bpSaved            65370 non-null  float64
#  44  l_bpFaced            65370 non-null  float64
#  45  winner_rank          71274 non-null  float64
#  46  winner_rank_points   71274 non-null  float64
#  47  loser_rank           70402 non-null  float64
#  48  loser_rank_points    70402 non-null  float64
#  49  year                 71830 non-null  int64
#  50  tourney_name_clean   71830 non-null  object
#  51  mapped_tourney_name  31416 non-null  object
#  52  winner_name_clean    71830 non-null  object
#  53  loser_name_clean     71830 non-null  object
#  54  Tournament_clean     0 non-null      object
#  55  Winner_clean         0 non-null      object
#  56  Loser_clean          0 non-null      object
#  57  B365W                0 non-null      float64
#  58  B365L                0 non-null      float64
# dtypes: datetime64[ns](1), float64(31), int64(6), object(21)
# memory usage: 32.3+ MB
